# %% [markdown]
# <a href="https://colab.research.google.com/github/JinLeeGG/AI_Project_Preparation/blob/main/Unit2%20(Dictionary%20%26%20Sets)/Standard_Problem_Set_Version_1_(Session1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def lineup(artists, set_times):
    a = zip(artists, set_times)
    return dict(a)

# %%
artists1 = ["Kendrick Lamar", "Chappell Roan", "Mitski", "Rosalia"]
set_times1 = ["9:30 PM", "5:00 PM", "2:00 PM", "7:30 PM"]

artists2 = []
set_times2 = []

print(lineup(artists1, set_times1))
print(lineup(artists2, set_times2))
# Out:
# {'Kendrick Lamar': '9:30 PM', 'Chappell Roan': '5:00 PM', 'Mitski': '2:00 PM', 'Rosalia': '7:30 PM'}
# {}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def get_artist_info(artist, festival_schedule):
    d = {"message":"Artist not found"}

    info = festival_schedule.get(artist)
    if info == None:
      return d
    return info

# %%
festival_schedule = {
    "Blood Orange": {"day": "Friday", "time": "9:00 PM", "stage": "Main Stage"},
    "Metallica": {"day": "Saturday", "time": "8:00 PM", "stage": "Main Stage"},
    "Kali Uchis": {"day": "Sunday", "time": "7:00 PM", "stage": "Second Stage"},
    "Lawrence": {"day": "Friday", "time": "6:00 PM", "stage": "Main Stage"}
}

print(get_artist_info("Blood Orange", festival_schedule))
print(get_artist_info("Taylor Swift", festival_schedule))
# Out:
# {'day': 'Friday', 'time': '9:00 PM', 'stage': 'Main Stage'}
# {'message': 'Artist not found'}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def total_sales(ticket_sales):
  count = 0
  totalSales = ticket_sales.values()
  for sales in totalSales:
      count += sales

  return count

# %%
ticket_sales = {"Friday": 200, "Saturday": 1000, "Sunday": 800, "3-Day Pass": 2500}

print(total_sales(ticket_sales))
# Out:
# 4500

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def identify_conflicts(venue1_schedule, venue2_schedule):
    result = {}
    for key, value in venue1_schedule.items():
        if key in venue2_schedule:
          if venue2_schedule[key] == value:
              result[key] = value
    return result

# %%
venue1_schedule = {
    "Stromae": "9:00 PM",
    "Janelle Monáe": "8:00 PM",
    "HARDY": "7:00 PM",
    "Bruce Springsteen": "6:00 PM"
}

venue2_schedule = {
    "Stromae": "9:00 PM",
    "Janelle Monáe": "10:30 PM",
    "HARDY": "7:00 PM",
    "Wizkid": "6:00 PM"
}

print(identify_conflicts(venue1_schedule, venue2_schedule))
# Out:
# {'Stromae': '9:00 PM', 'HARDY': '7:00 PM'}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def best_set(votes):
    count = {}
    for key, value in votes.items():
        if value in count:
            count[value] += 1
        else:
            count[value] = 1

    return max(count, key=count.get)

# %%
votes1 = {
    1234: "SZA",
    1235: "Yo-Yo Ma",
    1236: "Ethel Cain",
    1237: "Ethel Cain",
    1238: "SZA",
    1239: "SZA"
}

votes2 = {
    1234: "SZA",
    1235: "Yo-Yo Ma",
    1236: "Ethel Cain",
    1237: "Ethel Cain",
    1238: "SZA"
}

print(best_set(votes1))
print(best_set(votes2))
# Out:
# SZA
# SZA
