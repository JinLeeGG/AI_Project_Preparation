# %% [markdown]
# <a href="https://colab.research.google.com/github/JinLeeGG/AI_Project_Preparation/blob/main/3.%20Data%20Analysis/05.%20Folium/4_5_Folium.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://ryuzyproject.tistory.com/63
#
# Folium
# - https://python-visualization.github.io/folium/latest/

# %% [markdown]
# # 1. Folium
# Folium은 파이썬에서 대화형 지도(interactive map)를 생성할 수 있는 라이브러리입니다. 특히, 지리 데이터(Geospatial Data) 시각화에 최적화되어 있으며, 간단한 코드로 복잡한 지도 기능을 구현할 수 있도록 도와줍니다.

# %%
! pip install folium
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.11/dist-packages (0.19.7)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.11/dist-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from folium) (2.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.11/dist-packages (from folium) (2025.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (2025.6.15)

# %%
import folium

# %%
# 지도를 뿌리면서(.Map) 어디를 중심으로 지도를 뿌릴지 써준다. (location)
# 서울특별시청의 위경도를 넣는다.
map_folium = folium.Map(location=[37.56652479270633, 126.9779129116262], zoom_start=15)
# 팝업을 만들어서
popup = folium.Popup('서울특별시청', max_width=200)
# 팝업, 위경도정보를 마커에다가 집어넣는다.
folium.Marker(location=[37.56652479270633, 126.9779129116262], popup=popup).add_to(map_folium)

popup = folium.Popup('덕수궁', max_width=200)
folium.Marker(location=[37.56585320879458, 126.97514572197248], popup=popup).add_to(map_folium)

popup = folium.Popup('서울지방경찰청', max_width=200)
folium.Marker(location=[37.57504045678939, 126.97195576938117], popup=popup).add_to(map_folium)

popup = folium.Popup('광화문', max_width=200)
folium.Marker(location=[37.57617987638928, 126.97694467807803], popup=popup).add_to(map_folium)

popup = folium.Popup('영풍문고-종로본점', max_width=200)
folium.Marker(location=[37.56999947440024, 126.98228391170936], popup=popup).add_to(map_folium)

# %%
# 지도를 찍어준다.
map_folium
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a8e875464a14987d588e3a7c2940bd00 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a8e875464a14987d588e3a7c2940bd00&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a8e875464a14987d588e3a7c2940bd00 = L.map(
#                 &quot;map_a8e875464a14987d588e3a7c2940bd00&quot;,
#                 {
#                     center: [37.56652479270633, 126.9779129116262],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_08c1415253593767de71e6f4d635a51f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_08c1415253593767de71e6f4d635a51f.addTo(map_a8e875464a14987d588e3a7c2940bd00);
#
#
#             var marker_ee6430135cc2c9f626048ef7e43f728d = L.marker(
#                 [37.56652479270633, 126.9779129116262],
#                 {
# }
#             ).addTo(map_a8e875464a14987d588e3a7c2940bd00);
#
#
#         var popup_8dee943f1b526863c49b6935d6da2799 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_6467252b8d70b9d7edd2f781144683de = $(`&lt;div id=&quot;html_6467252b8d70b9d7edd2f781144683de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시청&lt;/div&gt;`)[0];
#                 popup_8dee943f1b526863c49b6935d6da2799.setContent(html_6467252b8d70b9d7edd2f781144683de);
#
#
#
#         marker_ee6430135cc2c9f626048ef7e43f728d.bindPopup(popup_8dee943f1b526863c49b6935d6da2799)
#         ;
#
#
#
#
#             var marker_c2904b2d6590913c15585b649c9f67d0 = L.marker(
#                 [37.56585320879458, 126.97514572197248],
#                 {
# }
#             ).addTo(map_a8e875464a14987d588e3a7c2940bd00);
#
#
#         var popup_d6a767f249813fd4f187c789fc1d2702 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_c061821424afc725d27b74863cd5d8fd = $(`&lt;div id=&quot;html_c061821424afc725d27b74863cd5d8fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;덕수궁&lt;/div&gt;`)[0];
#                 popup_d6a767f249813fd4f187c789fc1d2702.setContent(html_c061821424afc725d27b74863cd5d8fd);
#
#
#
#         marker_c2904b2d6590913c15585b649c9f67d0.bindPopup(popup_d6a767f249813fd4f187c789fc1d2702)
#         ;
#
#
#
#
#             var marker_c20fed1c011350e7b880c981f973fa30 = L.marker(
#                 [37.57504045678939, 126.97195576938117],
#                 {
# }
#             ).addTo(map_a8e875464a14987d588e3a7c2940bd00);
#
#
#         var popup_0e89c66fe0a6e4ae331c4220e5199039 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_434a31892446a92c07cf82a57892febc = $(`&lt;div id=&quot;html_434a31892446a92c07cf82a57892febc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울지방경찰청&lt;/div&gt;`)[0];
#                 popup_0e89c66fe0a6e4ae331c4220e5199039.setContent(html_434a31892446a92c07cf82a57892febc);
#
#
#
#         marker_c20fed1c011350e7b880c981f973fa30.bindPopup(popup_0e89c66fe0a6e4ae331c4220e5199039)
#         ;
#
#
#
#
#             var marker_f4d64020be112534cd0fb810cdcab328 = L.marker(
#                 [37.57617987638928, 126.97694467807803],
#                 {
# }
#             ).addTo(map_a8e875464a14987d588e3a7c2940bd00);
#
#
#         var popup_673d1dd693e0437e10c0511cd7bf49ad = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_7bea0b1bd71b3fd8c19f117ebe2415d2 = $(`&lt;div id=&quot;html_7bea0b1bd71b3fd8c19f117ebe2415d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;광화문&lt;/div&gt;`)[0];
#                 popup_673d1dd693e0437e10c0511cd7bf49ad.setContent(html_7bea0b1bd71b3fd8c19f117ebe2415d2);
#
#
#
#         marker_f4d64020be112534cd0fb810cdcab328.bindPopup(popup_673d1dd693e0437e10c0511cd7bf49ad)
#         ;
#
#
#
#
#             var marker_d10173297f30a90057f8f5f2d9144897 = L.marker(
#                 [37.56999947440024, 126.98228391170936],
#                 {
# }
#             ).addTo(map_a8e875464a14987d588e3a7c2940bd00);
#
#
#         var popup_7469c36c428025bfd848574c67e8b2a7 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_fe35a80898d910d5f9b5ccae30fd4180 = $(`&lt;div id=&quot;html_fe35a80898d910d5f9b5ccae30fd4180&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;영풍문고-종로본점&lt;/div&gt;`)[0];
#                 popup_7469c36c428025bfd848574c67e8b2a7.setContent(html_fe35a80898d910d5f9b5ccae30fd4180);
#
#
#
#         marker_d10

# %% [markdown]
# # iconfinder
# https://www.iconfinder.com/

# %%
# 커스텀 아이콘 사용법
from folium.features import CustomIcon

# 내 커스텀 아이콘
icon = CustomIcon('/content/drive/MyDrive/Python_Computer Vision With AI/3. Data Analysis/data/police.png', icon_size=(45, 45))

map_folium = folium.Map(location=[37.56652479270633, 126.9779129116262], zoom_start=15)
popup = folium.Popup('서울특별시청', max_width=200)

# 아이콘을 스타라는 빨간색 아이콘을 넣었다.
folium.Marker(location=[37.56652479270633, 126.9779129116262], popup=popup,
              icon=folium.Icon(icon='star', color='red')).add_to(map_folium)

# 아이콘을 ok라는 핑스색 버튼을 넣어줬다.
popup = folium.Popup('덕수궁', max_width=200)
folium.Marker(location=[37.56585320879458, 126.97514572197248], popup=popup,
              icon=folium.Icon(icon='ok', color='pink')).add_to(map_folium)

popup = folium.Popup('서울지방경찰청', max_width=200)
folium.Marker(location=[37.57504045678939, 126.97195576938117], popup=popup,
              icon=icon).add_to(map_folium)

popup = folium.Popup('광화문', max_width=200)
folium.Marker(location=[37.57617987638928, 126.97694467807803], popup=popup).add_to(map_folium)

# CircleMarker(): 원의 범위를 마커로 설정
# 동그랗게 범위를 주는 마커
popup = folium.Popup('내땅', max_width=200)
folium.CircleMarker(location=[37.56999947440024, 126.98228391170936], popup=popup,
              radius=30, color='red', fill_color='#ec4074').add_to(map_folium)

map_folium
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_10a9643bb6aa5c8065068a3d98a6e3ca {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_10a9643bb6aa5c8065068a3d98a6e3ca&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_10a9643bb6aa5c8065068a3d98a6e3ca = L.map(
#                 &quot;map_10a9643bb6aa5c8065068a3d98a6e3ca&quot;,
#                 {
#                     center: [37.56652479270633, 126.9779129116262],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9f5168c530e0c355df401b9a38696dde = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9f5168c530e0c355df401b9a38696dde.addTo(map_10a9643bb6aa5c8065068a3d98a6e3ca);
#
#
#             var marker_1485fed97bd6a20cf600f0d8a7566b97 = L.marker(
#                 [37.56652479270633, 126.9779129116262],
#                 {
# }
#             ).addTo(map_10a9643bb6aa5c8065068a3d98a6e3ca);
#
#
#             var icon_57450b9c113a911883222cb9a7ab0fc0 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;star&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_3b4a7d1594b308362b71392aaaf680c3 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_4e038732028c90c2bcfea96d94dfeb12 = $(`&lt;div id=&quot;html_4e038732028c90c2bcfea96d94dfeb12&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시청&lt;/div&gt;`)[0];
#                 popup_3b4a7d1594b308362b71392aaaf680c3.setContent(html_4e038732028c90c2bcfea96d94dfeb12);
#
#
#
#         marker_1485fed97bd6a20cf600f0d8a7566b97.bindPopup(popup_3b4a7d1594b308362b71392aaaf680c3)
#         ;
#
#
#
#
#                 marker_1485fed97bd6a20cf600f0d8a7566b97.setIcon(icon_57450b9c113a911883222cb9a7ab0fc0);
#
#
#             var marker_699f79e237447ef3568b947d55db1094 = L.marker(
#                 [37.56585320879458, 126.97514572197248],
#                 {
# }
#             ).addTo(map_10a9643bb6aa5c8065068a3d98a6e3ca);
#
#
#             var icon_06e9611cdde1fc6e09fb27ef67f4b6cf = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;pink&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;ok&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_891b9dc11c5732828d565a5fc84a6e1e = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_3321f4f5f942e3f2fbecafbcbd60858b = $(`&lt;div id=&quot;html_3321f4f5f942e3f2fbecafbcbd60858b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;덕수궁&lt;/div&gt;`)[0];
#                 popup_891b9dc11c5732828d565a5fc84a6e1e.setContent(html_3321f4f5f942e3f2fbecafbcbd60858b);
#
#
#
#         marker_699f79e237447ef3568b947d55db1094.bindPopup(popup_891b9dc11c5732828d565a5fc84a6e1e)
#         ;
#
#
#
#
#                 marker_699f79e237447ef3568b947d55db1094.setIcon(icon_06e9611cdde1fc6e09fb27ef67f4b6cf);
#
#
#             var marker_51c3d93d09e6de8cd11c657b3eadf10a = L.marker(
#                 [37.57504045678939, 126.97195576938117],
#                 {
# }
#             ).addTo(map_10a9643bb6aa5c8065068a3d98a6e3ca);
#
#
#         var icon_c022d66e3752b641ad1d0cf027ed8d4d = L.icon({
#   &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;,
#   &quot;iconSize&quot;: [45, 45],
# });
#
#
#         var popup_cd80686fe544895a6ba8176ad42a8b67 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_0841e08cbb60dca95e20726baacdcca1 = $(`&lt;div id=&quot;html_0841e08cbb60dca95e20726baacdcca1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울지방경찰청&lt;/div&gt;`)[0];
#                 popup_cd80686fe544895a6ba8176ad42a8b67.setContent(html_0841e08cbb60dca95e20726baacdcca1);
#
#
#
#         marker_51c3d93d09e6de8cd11c657b3eadf10a.bindPopup(popup_cd80686fe544895a6ba8176ad42a8b67)
#         ;
#
#
#
#
#                 marker_51c3d93d09e6de8cd11c657b3eadf10a.setIcon(icon_c022d66e3752b641ad1d0cf027ed8d4d);
#
#
#             var marker_f4a12d69af338b19f011116806875037 = L.marker(
#                 [37.57617987638928, 126.97694467807803],
#                 {
# }
#             ).addTo(map_10a9643bb6aa5c8065068a3d98a6e3ca);
#
#
#         var popup_
